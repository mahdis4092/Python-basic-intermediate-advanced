# %% [markdown]
# If Else statement

# %%
age = 16
if age>=18:
    print('You are eligible for vote')
else:
    print("You are not eligible for vote")
# Out:
# You are not eligible for vote

# %% [markdown]
# Iterative control(for , while loop)

# %%
#while
i = 1
while i<= 10:
    print("Iteration: ",i)
    i+=1
# Out:
# Iteration:  1
# Iteration:  2
# Iteration:  3
# Iteration:  4
# Iteration:  5
# Iteration:  6
# Iteration:  7
# Iteration:  8
# Iteration:  9
# Iteration:  10
